# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandraavisena/chandra-avisena/blob/main/anum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("\833c")
import numpy as np
from matplotlib import pyplot as plt
# Out:
# \833c

# %%
x_awal = -2.0
x_akhir = -1.0
dx = 10
err_m = 0.1
x = x_awal
y = 2*x*3 - 3*x*2 - 5*x + 3

i = 0
while(x < x_akhir and y*2 > err_m*2):
  i = i + 1
  x = x + dx
  y = 2*x*3 - 3*x*2 - 5*x + 3
  print("iterasi ke-", i)
  print("x =", x)
  print("y =", y)
  print(" ")
print("VARIABEL")
print("x_awal =", x_awal)
print("x_akhir =", x_akhir)
print("dx =", dx)
print("error margin untuk y =", err_m)
print("HASIL AKHIR")
if(y<err_m):
  print("Pencarian akar berhasil.")
else:
  print("pencarian akar gagal, silahkan perkecil dx atau perbesar error margin.")
print("Banyaknya iterasi:", 1)
print("x =", x)
print("y =", y)
print(" ")
x = np.linspace(-2,3,10000)
plt.figure(figsize=(6,6.5))
sumbu_x = x -x -0
y       = 2*x*3 - 3*x*2 - 5*x + 3
plt.plot(x, sumbu_x,              '-k')
plt.plot(x, (0.01-x*2)*0.5,     '-k')
plt.plot(x, -((0.01-x*2)*0.5),  '-k')
plt.plot(x,  y,                   '-g', label='y')
plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# iterasi ke- 1
# x = 8.0
# y = -37.0
#
# VARIABEL
# x_awal = -2.0
# x_akhir = -1.0
# dx = 10
# error margin untuk y = 0.1
# HASIL AKHIR
# Pencarian akar berhasil.
# Banyaknya iterasi: 1
# x = 8.0
# y = -37.0
